# %%
from sklearn.datasets import load_iris
iris=load_iris()
x=iris.data
y=iris.target
feautures=iris.feature_names
target=iris.target_names


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print("Test:",y_test)

print('\n')

from sklearn.neighbors import KNeighborsClassifier
model= KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)

pred=model.predict(x_test)
print("Prediction:",pred)
# Out:
# Test: [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 1 0 2 1 0 0 1 2]
#
#
# Prediction: [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 1 0 2 1 0 0 1 2]

# %%
from sklearn import metrics

accuracy=metrics.accuracy_score(y_test,pred)

accuracy
# Out:
# 1.0

# %%
new_data=[[5.0, 3.4, 1.5, 0.2],  # likely setosa
          [6.0, 2.7, 4.5, 1.5],  # likely versicolor
          [6.3, 3.3, 6.0, 2.5],  # likely virginica
          [5.5, 2.4, 3.7, 1.0],  # likely versicolor
          [4.8, 3.0, 1.4, 0.1]]  #likely setosa

Prediction=model.predict(new_data)
Predicted_species=[iris.target_names[p] for p in Prediction]

print(Predicted_species)
# Out:
# [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica'), np.str_('versicolor'), np.str_('setosa')]
